# %%
import requests
import json

# %%
def get_workspace_list(server,token=None):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}

    workspace_id = str(input("Enter Workspace ID\n"))
    #body
    payload = {
             "workspaceId": workspace_id
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 4))

    #validate response server for the header and body e.g status code
    assert resp.status_code == 200


    #print response full body as text

    print((resp.text))

# %%
get_workspace_list("http://localhost:8000/api/v1/workspaces/list",None)
# Out:
# Enter Workspace ID
# 44168763-ebb9-4c79-bf95-8703186ae249
# {"workspaces":[{"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249","customerId":"66c05d29-4944-4d7c-91f2-cb49ed4bad6e","email":"osamuyipeace@gmail.com","name":"44168763-ebb9-4c79-bf95-8703186ae249","slug":"44168763-ebb9-4c79-bf95-8703186ae249","initialSetupComplete":true,"displaySetupWizard":true,"anonymousDataCollection":true,"news":false,"securityUpdates":true,"notifications":[],"firstCompletedSync":null,"feedbackDone":null}]}

# %%
def get_connection_list(server,token=None):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}
    workspace_id = str(input("Enter Workspace ID\n"))
    #body
    payload = {
             "workspaceId": workspace_id
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 15))

    #print response full body as text

    print((resp.text))

# %%
get_connection_list("http://localhost:8000/api/v1/connections/list",None)
# Out:
# Enter Workspace ID
# 44168763-ebb9-4c79-bf95-8703186ae249
# {"connections":[{"connectionId":"13573289-9e49-4f1e-873b-c23ca85a88c1","name":"default","namespaceDefinition":"source","namespaceFormat":"${SOURCE_NAMESPACE}","prefix":"","sourceId":"584c18aa-997a-4fcc-9409-177129e61261","destinationId":"57b0ffea-f150-4190-91cb-e3e587c11f0a","operationIds":[],"syncCatalog":{"streams":[{"stream":{"name":"brands","jsonSchema":{"type":"object","properties":{"brand_id":{"type":"number"},"brand_name":{"type":"string"}}},"supportedSyncModes":["full_refresh","incremental"],"sourceDefinedCursor":null,"defaultCursorField":[],"sourceDefinedPrimaryKey":[["brand_id"]],"namespace":"production"},"config":{"syncMode":"full_refresh","cursorField":[],"destinationSyncMode":"append","primaryKey":[["brand_id"]],"aliasName":"brands","selected":true}},{"stream":{"name":"categories","jsonSchema":{"type":"object","properties":{"category_id":{"type":"number"},"category_name":{"type":"string"}}},"supportedSyncModes":["full_refresh","incremental"],"sourceDefinedCursor":null,"defaultCursorField":[],"sourceDefinedPrimaryKey":[["category_id"]],"namespace":"production"},"config":{"syncMode":"full_refresh","cursorField":[],"destinationSyncMode":"append","primaryKey":[["category_id"]],"aliasName":"categories","selected":true}},{"stream":{"name":"customers","jsonSchema":{"type":"object","properties":{"city":{"type":"string"},"email":{"type":"string"},"phone":{"type":"string"},"state":{"type":"string"},"street":{"type":"string"},"zip_code":{"type":"string"},"last_name":{"type":"string"},"first_name":{"type":"string"},"customer_id":{"type":"number"}}},"supportedSyncModes":["full_refresh","incremental"],"sourceDefinedCursor":null,"defaultCursorField":[],"sourceDefinedPrimaryKey":[["customer_id"]],"namespace":"sales"},"config":{"syncMode":"full_refresh","cursorField":[],"destinationSyncMode":"append","primaryKey":[["customer_id"]],"aliasName":"customers","selected":true}},{"stream":{"name":"order_items","jsonSchema":{"type":"object","properties":{"item_id":{"type":"number"},"discount":{"type":"number"},"order_id":{"type":"number"},"quantity":{"type":"number"},"list_price":{"type":"number"},"product_id":{"type":"number"}}},"supportedSyncModes":["full_refresh","incremental"],"sourceDefinedCursor":null,"defaultCursorField":[],"sourceDefinedPrimaryKey":[["order_id"],["item_id"]],"namespace":"sales"},"config":{"syncMode":"full_refresh","cursorField":[],"destinationSyncMode":"append","primaryKey":[["order_id"],["item_id"]],"aliasName":"order_items","selected":true}},{"stream":{"name":"orders","jsonSchema":{"type":"object","properties":{"order_id":{"type":"number"},"staff_id":{"type":"number"},"store_id":{"type":"number"},"order_date":{"type":"string"},"customer_id":{"type":"number"},"order_status":{"type":"number"},"shipped_date":{"type":"string"},"required_date":{"type":"string"}}},"supportedSyncModes":["full_refresh","incremental"],"sourceDefinedCursor":null,"defaultCursorField":[],"sourceDefinedPrimaryKey":[["order_id"]],"namespace":"sales"},"config":{"syncMode":"full_refresh","cursorField":[],"destinationSyncMode":"append","primaryKey":[["order_id"]],"aliasName":"orders","selected":true}},{"stream":{"name":"products","jsonSchema":{"type":"object","properties":{"brand_id":{"type":"number"},"list_price":{"type":"number"},"model_year":{"type":"number"},"product_id":{"type":"number"},"category_id":{"type":"number"},"product_name":{"type":"string"}}},"supportedSyncModes":["full_refresh","incremental"],"sourceDefinedCursor":null,"defaultCursorField":[],"sourceDefinedPrimaryKey":[["product_id"]],"namespace":"production"},"config":{"syncMode":"full_refresh","cursorField":[],"destinationSyncMode":"append","primaryKey":[["product_id"]],"aliasName":"products","selected":true}},{"stream":{"name":"staffs","jsonSchema":{"type":"object","properties":{"email":{"type":"string"},"phone":{"type":"string"},"active":{"type":"number"},"staff_id":{"type":"number"},"store_id":{"type":"number"},"last_name":{"type":"string"},"first_name":{"type":"string"},"m ...

# %%
def trigger_manual_sync(server,token=None):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}
    
    connection_id = str(input("Enter Connection ID\n"))
    #body
    payload = {
             "connectionId": connection_id
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 4))

    #print response full body as text

    print((resp.text))

# %%
trigger_manual_sync("http://localhost:8000/api/v1/connections/sync",None)
# Out:
# Enter Connection ID
# 13573289-9e49-4f1e-873b-c23ca85a88c1
# {"job":{"id":11,"configType":"sync","configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","createdAt":1645703656,"updatedAt":1645703656,"status":"pending"},"attempts":[]}

# %%
def get_log(server,token=None):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}
    print("The allowed logtype include server log or scheduler log ")
    
    logtype = str(input("Enter logtype\n"))
    #body
    payload = {
             "logType": logtype
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 4))

    #print response full body as text

    print((resp.text))

# %%
get_log("http://localhost:8000/api/v1/logs/get", None)
# Out:
# The allowed logtype include server log or scheduler log
# Enter logtype
# server
# 2022-02-17 14:37:00 INFO i.a.s.ServerApp(getServer):151 - Checking databases..
# 2022-02-17 14:37:00 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable CONFIG_DATABASE_USER: 'docker'
# 2022-02-17 14:37:00 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable CONFIG_DATABASE_PASSWORD: '*****'
# 2022-02-17 14:37:00 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable CONFIG_DATABASE_URL: 'jdbc:postgresql://db:5432/airbyte'
# 2022-02-17 14:37:00 INFO i.a.s.ServerApp(assertDatabasesReady):128 - Checking configs database flyway migration version..
# 2022-02-17 14:37:00 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertDatabase):42 - Waiting for database...
# 2022-02-17 14:37:00 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:00 INFO i.a.d.i.BaseDatabaseInstance(lambda$isDatabaseConnected$5):127 - Testing airbyte configs database connection...
# 2022-02-17 14:37:02 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):74 - Database is not ready yet. Please wait a moment, it might still be initializing...
# 2022-02-17 14:37:07 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:07 INFO i.a.d.i.BaseDatabaseInstance(lambda$isDatabaseConnected$5):127 - Testing airbyte configs database connection...
# 2022-02-17 14:37:07 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):74 - Database is not ready yet. Please wait a moment, it might still be initializing...
# 2022-02-17 14:37:12 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:12 INFO i.a.d.i.BaseDatabaseInstance(lambda$isDatabaseConnected$5):127 - Testing airbyte configs database connection...
# 2022-02-17 14:37:13 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):90 - Database available!
# 2022-02-17 14:37:13 INFO i.a.d.Databases(createPostgresDatabaseWithRetry):48 - Database available!
# 2022-02-17 14:37:13 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$isInitialized$4):65 - The airbyte configs database is not initialized; initializing it with schema
# 2022-02-17 14:37:19 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertDatabase):42 - Waiting for database...
# 2022-02-17 14:37:19 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$isInitialized$4):62 - The airbyte configs database is initialized
# 2022-02-17 14:37:19 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:19 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$static$3):28 - Testing if airbyte_configs has been created and seeded...
# 2022-02-17 14:37:19 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):74 - Database is not ready yet. Please wait a moment, it might still be initializing...
# 2022-02-17 14:37:24 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:24 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$static$3):28 - Testing if airbyte_configs has been created and seeded...
# 2022-02-17 14:37:24 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):74 - Database is not ready yet. Please wait a moment, it might still be initializing...
# 2022-02-17 14:37:29 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:29 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$static$3):28 - Testing if airbyte_configs has been created and seeded...
# 2022-02-17 14:37:29 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):74 - Database is not ready yet. Please wait a moment, it might still be initializing...
# 2022-02-17 14:37:34 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:34 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$static$3):28 - Testing if airbyte_configs has been created and seeded...
# 2022-02-17 14:37:34 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):74 - Database is not ready yet. Please wait a moment, it might still be initializing...
# 2022-02-17 14:37:39 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:39 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$static$3):28 - Testing if airbyte_configs has been created and seeded...
# 2022-02-17 14:37:39 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):90 - Database available!
# 2022-02-17 14:37:39 INFO i.a.d.Databases(createPostgresDatabaseWithRetry):48 - Database available!
# 2022-02-17 14:37:39 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable CONFIGS_DATABASE_INITIALIZATION_TIMEOUT_MS: '60000'
# 2022-02-17 14:37:39 INFO o.f.c.i.l.s.Slf4jLog(info):49 - Flyway Community Edition 7.14.0 by Redgate
# 2022-02-17 14:37:39 INFO o.f.c.i.l.s.Slf4jLog(info):49 - Database: jdbc:postgresql://db:5432/airbyte (PostgreSQL 13.5)
# 2022-02-17 14:37:39 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertMigrations):76 - Current database migration version 0.35.15.001
# 2022-02-17 14:37:39 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertMigrations):77 - Minimum Flyway version required 0.35.15.001
# 2022-02-17 14:37:39 INFO i.a.s.ServerApp(assertDatabasesReady):134 - Checking jobs database flyway migration version..
# 2022-02-17 14:37:39 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertDatabase):42 - Waiting for database...
# 2022-02-17 14:37:39 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:39 INFO i.a.d.i.BaseDatabaseInstance(lambda$isDatabaseConnected$5):127 - Testing airbyte jobs database connection...
# 2022-02-17 14:37:40 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):90 - Database available!
# 2022-02-17 14:37:40 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:40 INFO i.a.d.i.j.JobsDatabaseInstance(lambda$static$2):25 - Testing if jobs database is ready...
# 2022-02-17 14:37:40 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):90 - Database available!
# 2022-02-17 14:37:40 INFO i.a.d.Databases(createPostgresDatabaseWithRetry):48 - Database available!
# 2022-02-17 14:37:40 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable JOBS_DATABASE_INITIALIZATION_TIMEOUT_MS: '60000'
# 2022-02-17 14:37:40 INFO o.f.c.i.l.s.Slf4jLog(info):49 - Flyway Community Edition 7.14.0 by Redgate
# 2022-02-17 14:37:40 INFO o.f.c.i.l.s.Slf4jLog(info):49 - Database: jdbc:postgresql://db:5432/airbyte (PostgreSQL 13.5)
# 2022-02-17 14:37:40 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertMigrations):76 - Current database migration version 0.29.0.001
# 2022-02-17 14:37:40 INFO i.a.d.i.MinimumFlywayMigrationVersionCheck(assertMigrations):77 - Minimum Flyway version required 0.29.15.001
# 2022-02-17 14:37:46 INFO o.f.c.i.l.s.Slf4jLog(info):49 - Flyway Community Edition 7.14.0 by Redgate
# 2022-02-17 14:37:46 INFO i.a.s.ServerApp(getServer):158 - Creating Staged Resource folder...
# 2022-02-17 14:37:46 INFO i.a.s.ServerApp(getServer):161 - Creating config repository...
# 2022-02-17 14:37:46 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:46 INFO i.a.d.i.c.ConfigsDatabaseInstance(lambda$static$3):28 - Testing if airbyte_configs has been created and seeded...
# 2022-02-17 14:37:46 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):90 - Database available!
# 2022-02-17 14:37:46 INFO i.a.d.Databases(createPostgresDatabaseWithRetry):48 - Database available!
# 2022-02-17 14:37:46 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable SECRET_PERSISTENCE: 'NONE'
# 2022-02-17 14:37:46 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable SECRET_PERSISTENCE: 'NONE'
# 2022-02-17 14:37:46 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable SECRET_PERSISTENCE: 'NONE'
# 2022-02-17 14:37:46 INFO i.a.s.ServerApp(getServer):170 - Creating jobs persistence...
# 2022-02-17 14:37:46 WARN i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):65 - Waiting for database to become available...
# 2022-02-17 14:37:46 INFO i.a.d.i.j.JobsDatabaseInstance(lambda$static$2):25 - Testing if jobs database is ready...
# 2022-02-17 14:37:46 INFO i.a.d.Databases(createPostgresDatabaseWithRetryTimeout):90 - Database available!
# 2022-02-17 14:37:46 INFO i.a.d.Databases(createPostgresDatabaseWithRetry):48 - Database available!
# 2022-02-17 14:37:46 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable DEPLOYMENT_MODE: 'OSS'
# 2022-02-17 14:37:46 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable WORKER_ENVIRONMENT: 'DOCKER'
# 2022-02-17 14:37:47 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable ACTIVITY_MAX_ATTEMPT: '10'
# 2022-02-17 14:37:47 INFO i.a.c.EnvConfigs(getEnvOrDefault):662 - Using default value for environment variable ACTIVITY_MAX_TIMEOUT_SECOND: '30'
# 2022-02-17 14:37:47 INFO i.a.w.t.TemporalUtils(getTemporalClientWhenConnected):173 - Waiting for temporal server...
# 2022-02-17 14:37:47 WARN i.a.w.t.TemporalUtils(getTemporalClientWhenConnected):184 - Waiting for default namespace to be initialized in temporal...
# 2022-02-17 14:37:51 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:51 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:51 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:51 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:52 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:53 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:54 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:37:58 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:38:04 WARN i.a.w.t.TemporalUtils(getTemporalClientWhenConnected):193 - Ignoring exception while trying to request Temporal namespaces:
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.lambda$createTemporalService$0(TemporalUtils.java:60) ~[io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.getTemporalClientWhenConnected(TemporalUtils.java:189) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.workers.temporal.TemporalUtils.createTemporalService(TemporalUtils.java:56) [io.airbyte-airbyte-workers-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.getServer(ServerApp.java:184) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# 	at io.airbyte.server.ServerApp.main(ServerApp.java:236) [io.airbyte-airbyte-server-0.35.28-alpha.jar:?]
# Caused by: io.grpc.netty.shaded.io.netty.channel.AbstractChannel$AnnotatedConnectException: finishConnect(..) failed: Connection refused: airbyte-temporal/172.18.0.3:7233
# Caused by: java.net.ConnectException: finishConnect(..) failed: Connection refused
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.newConnectException0(Errors.java:155) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Errors.handleConnectErrno(Errors.java:128) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.unix.Socket.finishConnect(Socket.java:278) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.doFinishConnect(AbstractEpollChannel.java:710) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.finishConnect(AbstractEpollChannel.java:687) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.AbstractEpollChannel$AbstractEpollUnsafe.epollOutReady(AbstractEpollChannel.java:567) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.processReady(EpollEventLoop.java:470) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.channel.epoll.EpollEventLoop.run(EpollEventLoop.java:378) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:989) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at io.grpc.netty.shaded.io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30) ~[grpc-netty-shaded-1.42.1.jar:1.42.1]
# 	at java.lang.Thread.run(Thread.java:833) ~[?:?]
# 2022-02-17 14:38:04 WARN i.a.w.t.TemporalUtils(getTemporalClientWhenConnected):184 - Waiting for default namespace to be initialized in temporal...
# 2022-02-17 14:38:06 WARN i.t.i.r.GrpcSyncRetryer(retry):56 - Retrying after failure
# io.grpc.StatusRuntimeException: UNAVAILABLE: io exception
# 	at io.grpc.stub.ClientCalls.toStatusRuntimeException(ClientCalls.java:262) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.getUnchecked(ClientCalls.java:243) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.stub.ClientCalls.blockingUnaryCall(ClientCalls.java:156) ~[grpc-stub-1.42.1.jar:1.42.1]
# 	at io.grpc.health.v1.HealthGrpc$HealthBlockingStub.check(HealthGrpc.java:252) ~[grpc-services-1.42.1.jar:1.42.1]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.lambda$checkHealth$2(WorkflowServiceStubsImpl.java:282) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcSyncRetryer.retry(GrpcSyncRetryer.java:61) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.internal.retryer.GrpcRetryer.retryWithResult(GrpcRetryer.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.checkHealth(WorkflowServiceStubsImpl.java:275) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubsImpl.<init>(WorkflowServiceStubsImpl.java:182) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:51) ~[temporal-serviceclient-1.6.0.jar:?]
# 	at io.temporal.serviceclient.WorkflowServiceStubs.newInstance(WorkflowServiceStubs.java:41) ~[temporal-serviceclient-1.6.0.jar:?]
# ...
# 2022-02-23 21:22:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:22:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:23:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:23:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:23:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:24:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:24:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:24:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:25:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:25:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:25:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:26:54 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:27:54 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:28:50 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 OPTIONS 200 /api/v1/jobs/list
# 2022-02-23 21:28:50 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configTypes":["check_connection_source"],"configId":"string","pagination":{"pageSize":0,"rowOffset":0}}
# 2022-02-23 21:28:54 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:29:54 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:29:56 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:29:57 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/workspaces/get - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:29:58 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/sources/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:29:58 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/web_backend/connections/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:29:59 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/source_definitions/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:29:59 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/source_definitions/list_latest - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:30:04 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destination_definitions/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:30:05 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destination_definitions/list_latest - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:30:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:30:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"connectionId":"13573289-9e49-4f1e-873b-c23ca85a88c1"}
# 2022-02-23 21:30:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/source_definitions/get - {"sourceDefinitionId":"b5ea17b1-f170-46dc-bc31-cc744ca984c1"}
# 2022-02-23 21:30:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destination_definitions/get - {"destinationDefinitionId":"25c5221d-dce2-4163-ade9-739ef790f503"}
# 2022-02-23 21:30:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/web_backend/connections/get - {"destinationDefinitionId":"25c5221d-dce2-4163-ade9-739ef790f503"}
# 2022-02-23 21:30:16 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destinations/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:30:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:30:35 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configTypes":["check_connection_source"],"configId":"584c18aa-997a-4fcc-9409-177129e61261","pagination":{"pageSize":0,"rowOffset":0}}
# 2022-02-23 21:30:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:31:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:31:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:31:35 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configTypes":["check_connection_source"],"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","pagination":{"pageSize":0,"rowOffset":0}}
# 2022-02-23 21:31:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:31:51 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configTypes":["sync"],"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","pagination":{"pageSize":0,"rowOffset":0}}
# 2022-02-23 21:32:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:32:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:32:34 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configTypes":["sync"],"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","pagination":{"pageSize":1,"rowOffset":1}}
# 2022-02-23 21:32:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:33:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:33:10 ERROR i.a.s.RequestLogger(filter):93 - REQ 172.18.0.2 POST 422 /api/v1/jobs/list - {"configTypes":["check_conection_source"],"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","pagination":{"pageSize":1,"rowOffset":1}}
# 2022-02-23 21:33:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:33:44 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configTypes":["check_connection_source"],"configId":"584c18aa-997a-4fcc-9409-177129e61261","pagination":{"pageSize":1,"rowOffset":1}}
# 2022-02-23 21:33:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:34:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:34:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:34:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:35:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:35:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:35:32 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 OPTIONS 200 /api/v1/jobs/get
# 2022-02-23 21:35:32 ERROR i.a.s.RequestLogger(filter):93 - REQ 172.18.0.2 POST 400 /api/v1/jobs/get
# 2022-02-23 21:35:47 ERROR i.a.s.RequestLogger(filter):93 - REQ 172.18.0.2 POST 422 /api/v1/jobs/get - {"workspaceId":"8"}
# 2022-02-23 21:35:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:35:55 ERROR i.a.s.RequestLogger(filter):93 - REQ 172.18.0.2 POST 422 /api/v1/jobs/get - {"workspaceId":"8"}
# 2022-02-23 21:36:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:36:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":"8"}
# 2022-02-23 21:36:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:36:39 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":"9"}
# 2022-02-23 21:36:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:37:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:37:12 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 OPTIONS 200 /api/v1/health
# 2022-02-23 21:37:12 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:37:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:37:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:38:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:38:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:38:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:39:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:39:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:39:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:40:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:40:27 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:40:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:40:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:41:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:41:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:41:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:42:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:42:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:42:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:43:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:43:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:43:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:44:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:44:10 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destination_definitions/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:44:10 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/workspaces/get - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:44:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/source_definitions/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:44:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/web_backend/connections/list - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:44:11 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destination_definitions/list_latest - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:44:12 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/source_definitions/list_latest - {"workspaceId":"44168763-ebb9-4c79-bf95-8703186ae249"}
# 2022-02-23 21:44:13 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/source_definitions/get - {"sourceDefinitionId":"b5ea17b1-f170-46dc-bc31-cc744ca984c1"}
# 2022-02-23 21:44:13 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"sourceDefinitionId":"b5ea17b1-f170-46dc-bc31-cc744ca984c1"}
# 2022-02-23 21:44:13 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/destination_definitions/get - {"sourceDefinitionId":"b5ea17b1-f170-46dc-bc31-cc744ca984c1"}
# 2022-02-23 21:44:14 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/web_backend/connections/get - {"sourceDefinitionId":"b5ea17b1-f170-46dc-bc31-cc744ca984c1"}
# 2022-02-23 21:44:16 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:19 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:22 INFO i.a.c.f.EnvVariableFeatureFlags(usesNewScheduler):14 - New Scheduler: false
# 2022-02-23 21:44:22 INFO i.a.s.p.DefaultJobPersistence(enqueueJob):138 - enqueuing pending job for scope: 13573289-9e49-4f1e-873b-c23ca85a88c1
# 2022-02-23 21:44:22 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/connections/reset - {"connectionId":"13573289-9e49-4f1e-873b-c23ca85a88c1"}
# 2022-02-23 21:44:27 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:44:29 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:32 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:34 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:37 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:37 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":10}
# 2022-02-23 21:44:37 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get_debug_info - {"id":10}
# 2022-02-23 21:44:39 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:40 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":10}
# 2022-02-23 21:44:42 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:42 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":10}
# 2022-02-23 21:44:44 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:45 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":10}
# 2022-02-23 21:44:47 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/list - {"configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","configTypes":["sync","reset_connection"]}
# 2022-02-23 21:44:47 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/jobs/get - {"id":10}
# 2022-02-23 21:44:49 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:45:09 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 GET 200 /api/v1/health
# 2022-02-23 21:45:12 INFO i.a.s.RequestLogger(filter):95 - REQ 172.18.0.2 POST 200 /api/v1/logs/get - {"logType":"server"}

# %%
def get_recent_connection_job(server,token=None):
    url = server
    print("The allowed config type include: check_connection_source,check_connection_destination,discover_schema,get_spec,sync,reset_connection")
    #headers
    headers = {'Content-Type':'application/json'}
    
    configtype = str(input("Enter config type\n"))
    configI_id = str(input("Enter config id\n"))
    page_size= int(input("Enter page size"))
    row_offset= int(input("Enter row offset"))
    #body
    payload = {
             
          "configTypes": [
            configtype
              ],
          "configId": configI_id,
              "pagination": {
            "pageSize": page_size,
            "rowOffset": row_offset
  }
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 4))

    #print response full body as text

    print((resp.text))

# %%
recent_connection_job("http://localhost:8000/api/v1/jobs/list",None)
# Out:
# The allowed config type include: check_connection_source,check_connection_destination,discover_schema,get_spec,sync,reset_connection
# Enter config type
# check_connection_source
# Enter config id
# 584c18aa-997a-4fcc-9409-177129e61261
# Enter page size1
# Enter row offset1
# {"jobs":[]}

# %%
def get_job_info(server,token=None):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}

    job_id = str(input("Enter Job ID\n"))
    #body
    payload = {
             "id": job_id
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 4))

   


    #print response full body as text

    print((resp.text))

# %%
get_job_info("http://localhost:8000/api/v1/jobs/get")
# Out:
# Enter Job ID
# 10
# {"job":{"id":10,"configType":"reset_connection","configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","createdAt":1645652662,"updatedAt":1645652681,"status":"succeeded"},"attempts":[{"attempt":{"id":0,"status":"succeeded","createdAt":1645652662,"updatedAt":1645652681,"endedAt":1645652681,"bytesSynced":0,"recordsSynced":0,"totalStats":{"recordsEmitted":0,"bytesEmitted":0,"stateMessagesEmitted":1,"recordsCommitted":0},"streamStats":[],"failureSummary":null},"logs":{"logLines":["2022-02-23 21:44:23 \u001BINFO\u001B[m i.a.w.w.WorkerRun(call):49 - Executing worker wrapper. Airbyte version: 0.35.28-alpha","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.t.TemporalAttemptExecution(get):105 - Docker volume job log path: /tmp/workspace/10/0/logs.log","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.t.TemporalAttemptExecution(get):110 - Executing worker wrapper. Airbyte version: 0.35.28-alpha","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.DefaultReplicationWorker(run):103 - start sync worker. job id: 10 attempt id: 0","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.DefaultReplicationWorker(run):115 - configured sync modes: {sales.order_items=full_refresh - overwrite, sales.orders=full_refresh - overwrite, production.products=full_refresh - overwrite, production.stocks=full_refresh - overwrite, sales.staffs=full_refresh - overwrite, sales.customers=full_refresh - overwrite, production.brands=full_refresh - overwrite, production.categories=full_refresh - overwrite, sales.stores=full_refresh - overwrite}","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.p.a.DefaultAirbyteDestination(start):69 - Running destination...","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.c.i.LineGobbler(voidCall):82 - Checking if airbyte/destination-postgres:0.3.13 exists...","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.c.i.LineGobbler(voidCall):82 - airbyte/destination-postgres:0.3.13 was found locally.","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.p.DockerProcessFactory(create):157 - Preparing command: docker run --rm --init -i -w /data/10/0 --log-driver none --network host -v airbyte_workspace:/data -v /tmp/airbyte_local:/local airbyte/destination-postgres:0.3.13 write --config destination_config.json --catalog destination_catalog.json","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.DefaultReplicationWorker(run):157 - Waiting for source and destination threads to complete.","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.DefaultReplicationWorker(lambda$getDestinationOutputRunnable$6):337 - Destination output thread started.","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.DefaultReplicationWorker(lambda$getReplicationRunnable$5):278 - Replication thread started.","2022-02-23 21:44:24 \u001BINFO\u001B[m i.a.w.DefaultReplicationWorker(run):162 - One of source or destination thread complete. Waiting on the other.","2022-02-23 21:44:31 \u001Bdestination\u001B > 2022-02-23 21:44:31 \u001BINFO\u001B[m i.a.i.d.p.PostgresDestination(main):69 - {} - starting destination: class io.airbyte.integrations.destination.postgres.PostgresDestination","2022-02-23 21:44:31 \u001Bdestination\u001B > 2022-02-23 21:44:31 \u001BINFO\u001B[m i.a.i.b.IntegrationRunner(run):76 - {} - Running integration: io.airbyte.integrations.base.ssh.SshWrappedDestination","2022-02-23 21:44:31 \u001Bdestination\u001B > 2022-02-23 21:44:31 \u001BINFO\u001B[m i.a.i.b.IntegrationCliParser(parseOptions):118 - {} - integration args: {catalog=destination_catalog.json, write=null, config=destination_config.json}","2022-02-23 21:44:31 \u001Bdestination\u001B > 2022-02-23 21:44:31 \u001BINFO\u001B[m i.a.i.b.IntegrationRunner(run):80 - {} - Command: WRITE","2022-02-23 21:44:31 \u001Bdestination\u001B > 2022-02-23 21:44:31 \u001BINFO\u001B[m i.a.i.b.IntegrationRunner(run):81 - {} - Integration config: IntegrationConfig{command=WRITE, configPath='destination_config.json', catalogPath='destination_catalog.json', statePath='null'}","2022-02-23 21:44:31 \u001Bdestination\u001B > 2022-02-23 21:44:31 \u001BWARN\u001B[m c.n.s.JsonMetaSchema ...

# %%
def airbyte_health_status(server):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}

     
    resp_code = requests.get(url,headers= headers)
    print(resp_code)
    response_result= (json.dumps(resp_code.json(),indent= 4))

    #validate response server for the header and body e.g status code
    assert resp_code.status_code == 200


    #print response full body as text

    print(response_result)

# %%
 airbyte_health_status("http://localhost:8000/api/v1/health")
# Out:
# <Response [200]>
# {
#     "available": true
# }

# %%
def reset_connection_job(server,token=None):
    url = server

    #headers
    headers = {'Content-Type':'application/json'}
    
    connection_id = str(input("Enter Connection ID\n"))
    #body
    payload = {
             "connectionId": connection_id
    
    }

    #convert dict to json string
    resp = requests.post(url,headers= headers,data= json.dumps(payload,indent= 4))

    #print response full body as text

    print((resp.text))

# %%
reset_connection_job("http://localhost:8000/api/v1/connections/reset", None)
# Out:
# Enter Connection ID
# 13573289-9e49-4f1e-873b-c23ca85a88c1
# {"job":{"id":10,"configType":"reset_connection","configId":"13573289-9e49-4f1e-873b-c23ca85a88c1","createdAt":1645652662,"updatedAt":1645652662,"status":"pending"},"attempts":[]}
